# %% [markdown]
# Question 6

# %%
from scipy.stats import norm

mu = 0.147
sigma = 0.33


p_loss = norm.cdf(0, loc=mu, scale=sigma)
p_loss
# Out:
# np.float64(0.3279956507031998)

# %%
cutoff = norm.ppf(0.85, loc=mu, scale=sigma)
cutoff
# Out:
# np.float64(0.4890230185329506)
